# %%
# !pip install -q transformers
# !pip install -q tf-models-official==2.2.0
# !pip install datasets

# %%
# !git clone https://github.com/dt024/VLSP2021_MRC.git

# %%
import os
import time
import datetime
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from transformers import AutoTokenizer, AutoConfig, AutoModel, BertModel, BertPreTrainedModel, BertConfig, RobertaConfig, RobertaModel, BertTokenizer, BertModel, RobertaTokenizer
from transformers import AdamW, BertConfig, get_linear_schedule_with_warmup
import torch.nn as nn
from torch.autograd import Function
import torch.optim as optim
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from official import nlp
import official.nlp.optimization
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler, WeightedRandomSampler
import logging
from tqdm import tqdm, trange

# %%
#Get the GPU device name
device_name = tf.test.gpu_device_name()

if device_name == '/device:GPU:0':
  print('GPU: {}'.format(device_name))
else:
  raise SystemError('GPU not found')
# Out:
# GPU: /device:GPU:0

# %%
# If there's a GPU
if torch.cuda.is_available():
  device = torch.device('cuda')
  torch.cuda.set_device(0)
  print('There are %d GPU(s).' % torch.cuda.device_count())
  print('We will use the GPU:', torch.cuda.get_device_name())
else:
  print('No GPU, using CPU.')
  device = torch.device('cpu')
# Out:
# There are 1 GPU(s).
# We will use the GPU: Tesla K80

# %%
base_dir    = 'VLSP2021_MRC/'
train_path  = os.path.join(base_dir, 'fix-train.csv')
val_path    = os.path.join(base_dir, 'fix-val.csv')

# %%
df_train = pd.read_csv(train_path)
print(df_train.shape)
print(df_train.info())
display(df_train.head())
# Out:
# (25614, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25614 entries, 0 to 25613
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          25614 non-null  object
#  1   context        25614 non-null  object
#  2   answer_text    25614 non-null  object
#  3   answer_start   25614 non-null  int64
#  4   id             25614 non-null  object
#  5   is_impossible  25614 non-null  bool
#  6   question       25614 non-null  object
#  7   answer_end     25614 non-null  int64
# dtypes: bool(1), int64(2), object(5)
# memory usage: 1.4+ MB
# None
#                             title  ... answer_end
# 0                            Pháp  ...        568
# 1                  Lịch sử Hoa Kỳ  ...        266
# 2  Trung Hoa Dân Quốc (1912-1949)  ...        230
# 3                            Iran  ...        497
# 4            Cách mạng Tháng Mười  ...        167
#
# [5 rows x 8 columns]

# %%
df_val = pd.read_csv(val_path)
print(df_val.shape)
print(df_val.info())

display(df_val.head())
# Out:
# (2846, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2846 entries, 0 to 2845
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          2846 non-null   object
#  1   context        2846 non-null   object
#  2   answer_text    2846 non-null   object
#  3   answer_start   2846 non-null   int64
#  4   id             2846 non-null   object
#  5   is_impossible  2846 non-null   bool
#  6   question       2846 non-null   object
#  7   answer_end     2846 non-null   int64
# dtypes: bool(1), int64(2), object(5)
# memory usage: 158.5+ KB
# None
#               title  ... answer_end
# 0      Donald Trump  ...        241
# 1   Michael Jackson  ...        250
# 2  Bức tường Berlin  ...        482
# 3          Nhà Minh  ...       1344
# 4     Đế quốc La Mã  ...        847
#
# [5 rows x 8 columns]

# %%
train_q  = df_train.question.values
train_a  = df_train.answer_text.values
train_c  = df_train.context.values
train_title = df_train.title.values
train_id = df_train.id.values
train_impossible = df_train.is_impossible.values
train_ans_start = df_train.answer_start.values
train_ans_end = df_train.answer_end.values

val_q  = df_val.question.values
val_a  = df_val.answer_text.values
val_c  = df_val.context.values
val_id = df_val.id.values
val_title = df_val.title.values
val_impossible = df_val.is_impossible.values
val_ans_start = df_val.answer_start.values
val_ans_end = df_val.answer_end.values

train_data = [train_id, train_q, train_title, train_c, train_a, train_impossible, train_ans_start]
val_data = [val_id, val_q, val_title, val_c, val_a, val_impossible, val_ans_start]

# %%
dev_answers = []
for i in range(len(val_id)):
  temp2 = {}
  temp2['id'] = val_id[i]
  temp = {}
  temp['answer_start'] = [val_ans_start[i]]
  temp['text'] = [val_a[i]]
  temp2['answers'] = temp
  dev_answers.append(temp2)

# %%
# Load the BERT tokenizer.
print('Loading BERT tokenizer...')
# tokenizer = AutoTokenizer.from_pretrained(MODEL, do_lower_case=False)
tokenizer = BertTokenizer.from_pretrained('NlpHUST/vibert4news-base-cased', do_lower_case=False)
# Out:
# Loading BERT tokenizer...
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RobertaTokenizer'.
# The class this function is called from is 'BertTokenizer'.

# %%
from VLSP2021_MRC.utils import init_logger
from VLSP2021_MRC.trainer import Trainer

# %%
class arg():
  def __init__(self):
    self.model_dir = '/MRC_bert4news'
    self.model_name_or_path = 'NlpHUST/vibert4news-base-cased'
    self.do_train = True
    self.do_eval = True
    self.no_cuda = False
    # self.logging_steps = 13         #Log every X updates steps
    # self.save_steps = 13            #Save checkpoint every X updates steps
    self.warmup_steps = 0
    self.max_grad_norm = 1.0
    self.adam_epsilon = 1e-8
    self.weight_decay = 0.01
    self.dropout_rate = 0.2
    self.max_steps = -1              #total number of training steps to perform
    self.gradient_accumulation_steps = 1     #Number of updates steps to accumulate before performing a backward/update pass
    self.num_train_epochs = 3
    self.learning_rate = 2e-5
    self.early_stop = 35
    self.train_batch_size = 8
    self.eval_batch_size = 8
    self.seed = 2021
    self.max_seq_length = 256
    self.doc_stride = 100
    self.max_query_length = 100
    self.do_lower_case= False
    self.version_2_with_negative = True
    self.null_score_diff_threshold=0.0
    self.n_best_size = 20
    self.max_answer_length = 256

# %%
args = arg()

# %%
def set_seed(args):
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    if not args.no_cuda and torch.cuda.is_available():
        torch.cuda.manual_seed_all(args.seed)

init_logger()
set_seed(args)

# %%
logger = logging.getLogger(__name__)

trainer = Trainer(args, train_dataset=train_data, dev_dataset=val_data, dev_answer=dev_answers, tokenizer=tokenizer)
# Out:
# convert squad examples to features: 100%|██████████| 25614/25614 [05:15<00:00, 81.10it/s]
# add example index and unique id: 100%|██████████| 25614/25614 [00:00<00:00, 568632.64it/s]
# convert squad examples to features: 100%|██████████| 2846/2846 [00:35<00:00, 80.88it/s]
# add example index and unique id: 100%|██████████| 2846/2846 [00:00<00:00, 391248.42it/s]
# Some weights of the model checkpoint at NlpHUST/vibert4news-base-cased were not used when initializing BertForQuestionAnswering: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at NlpHUST/vibert4news-base-cased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.train()
# Out:
# Streaming output truncated to the last 5000 lines.
# Unanswered question uit_026718 will receive score 0.
# Unanswered question uit_002055 will receive score 0.
# Unanswered question uit_004424 will receive score 0.
# Unanswered question uit_000640 will receive score 0.
# Unanswered question uit_013856 will receive score 0.
# Unanswered question uit_026658 will receive score 0.
# Unanswered question uit_021966 will receive score 0.
# Unanswered question uit_026597 will receive score 0.
# Unanswered question uit_013836 will receive score 0.
# Unanswered question uit_013588 will receive score 0.
# Unanswered question uit_016527 will receive score 0.
# Unanswered question uit_003240 will receive score 0.
# Unanswered question uit_015750 will receive score 0.
# Unanswered question uit_005230 will receive score 0.
# Unanswered question uit_013341 will receive score 0.
# Unanswered question uit_020970 will receive score 0.
# Unanswered question uit_004239 will receive score 0.
# Unanswered question uit_023537 will receive score 0.
# Unanswered question uit_005979 will receive score 0.
# Unanswered question uit_021467 will receive score 0.
# Unanswered question uit_024436 will receive score 0.
# Unanswered question uit_000317 will receive score 0.
# Unanswered question uit_018649 will receive score 0.
# Unanswered question uit_024752 will receive score 0.
# Unanswered question uit_022494 will receive score 0.
# Unanswered question uit_021680 will receive score 0.
# Unanswered question uit_000311 will receive score 0.
# Unanswered question uit_018732 will receive score 0.
# Unanswered question uit_027502 will receive score 0.
# Unanswered question uit_026493 will receive score 0.
# Unanswered question uit_010758 will receive score 0.
# Unanswered question uit_019235 will receive score 0.
# Unanswered question uit_009858 will receive score 0.
# Unanswered question uit_013656 will receive score 0.
# Unanswered question uit_028444 will receive score 0.
# Unanswered question uit_008357 will receive score 0.
# Unanswered question uit_010037 will receive score 0.
# Unanswered question uit_004658 will receive score 0.
# Unanswered question uit_011399 will receive score 0.
# Unanswered question uit_011788 will receive score 0.
# Unanswered question uit_013119 will receive score 0.
# Unanswered question uit_010930 will receive score 0.
# Unanswered question uit_018972 will receive score 0.
# Unanswered question uit_022200 will receive score 0.
# Unanswered question uit_009697 will receive score 0.
# Unanswered question uit_027429 will receive score 0.
# Unanswered question uit_015860 will receive score 0.
# Unanswered question uit_003594 will receive score 0.
# Unanswered question uit_026238 will receive score 0.
# Unanswered question uit_026046 will receive score 0.
# Unanswered question uit_013081 will receive score 0.
# Unanswered question uit_012971 will receive score 0.
# Unanswered question uit_026258 will receive score 0.
# Unanswered question uit_001730 will receive score 0.
# Unanswered question uit_001725 will receive score 0.
# Unanswered question uit_004121 will receive score 0.
# Unanswered question uit_001783 will receive score 0.
# Unanswered question uit_023912 will receive score 0.
# Unanswered question uit_003344 will receive score 0.
# Unanswered question uit_025784 will receive score 0.
# Unanswered question uit_002965 will receive score 0.
# Unanswered question uit_027212 will receive score 0.
# Unanswered question uit_016279 will receive score 0.
# Unanswered question uit_021905 will receive score 0.
# Unanswered question uit_013429 will receive score 0.
# Unanswered question uit_013026 will receive score 0.
# Unanswered question uit_026663 will receive score 0.
# Unanswered question uit_014621 will receive score 0.
# Unanswered question uit_012291 will receive score 0.
# Unanswered question uit_004380 will receive score 0.
# Unanswered question uit_017822 will receive score 0.
# Unanswered question uit_022969 will receive score 0.
# Unanswered question uit_017504 will receive score 0.
# Unanswered question uit_000329 will receive score 0.
# Unanswered question uit_023482 will receive score 0.
# Unanswered question uit_004365 will receive score 0.
# Unanswered question uit_012308 will receive score 0.
# Unanswered question uit_018697 will receive score 0.
# Unanswered question uit_006454 will receive score 0.
# Unanswered question uit_020212 will receive score 0.
# Unanswered question uit_018758 will receive score 0.
# Unanswered question uit_015384 will receive score 0.
# Unanswered question uit_003183 will receive score 0.
# Unanswered question uit_002152 will receive score 0.
# Unanswered question uit_005385 will receive score 0.
# Unanswered question uit_018932 will receive score 0.
# Unanswered question uit_008880 will receive score 0.
# Unanswered question uit_027299 will receive score 0.
# Unanswered question uit_022697 will receive score 0.
# Unanswered question uit_010110 will receive score 0.
# Unanswered question uit_028321 will receive score 0.
# Unanswered question uit_019111 will receive score 0.
# Unanswered question uit_012675 will receive score 0.
# Unanswered question uit_004338 will receive score 0.
# Unanswered question uit_010875 will receive score 0.
# Unanswered question uit_027071 will receive score 0.
# Unanswered question uit_022640 will receive score 0.
# Unanswered question uit_022797 will receive score 0.
# Unanswered question uit_010994 will receive score 0.
# Unanswered question uit_008121 will receive score 0.
# Unanswered question uit_024734 will receive score 0.
# Unanswered question uit_009507 will receive score 0.
# Unanswered question uit_014138 will receive score 0.
# Unanswered question uit_009014 will receive score 0.
# Unanswered question uit_015097 will receive score 0.
# Unanswered question uit_016491 will receive score 0.
# Unanswered question uit_013234 will receive score 0.
# Unanswered question uit_010979 will receive score 0.
# Unanswered question uit_019594 will receive score 0.
# Unanswered question uit_016410 will receive score 0.
# Unanswered question uit_023478 will receive score 0.
# Unanswered question uit_018341 will receive score 0.
# Unanswered question uit_008865 will receive score 0.
# Unanswered question uit_023934 will receive score 0.
# Unanswered question uit_021126 will receive score 0.
# Unanswered question uit_014303 will receive score 0.
# Unanswered question uit_005153 will receive score 0.
# Unanswered question uit_018992 will receive score 0.
# Unanswered question uit_023609 will receive score 0.
# Unanswered question uit_015217 will receive score 0.
# Unanswered question uit_015173 will receive score 0.
# Unanswered question uit_007913 will receive score 0.
# Unanswered question uit_012740 will receive score 0.
# Unanswered question uit_026908 will receive score 0.
# Unanswered question uit_011648 will receive score 0.
# Unanswered question uit_025976 will receive score 0.
# Unanswered question uit_019659 will receive score 0.
# Unanswered question uit_016641 will receive score 0.
# Unanswered question uit_014551 will receive score 0.
# Unanswered question uit_011820 will receive score 0.
# Unanswered question uit_027267 will receive score 0.
# Unanswered question uit_004514 will receive score 0.
# Unanswered question uit_025948 will receive score 0.
# Unanswered question uit_019101 will receive score 0.
# Unanswered question uit_002336 will receive score 0.
# Unanswered question uit_009136 will receive score 0.
# Unanswered question uit_017338 will receive score 0.
# Unanswered question uit_017808 will receive score 0.
# Unanswered question uit_018787 will receive score 0.
# Unanswered question uit_009484 will receive score 0.
# Unanswered question uit_028084 will receive score 0.
# Unanswered question uit_026288 will receive score 0.
# Unanswered question uit_019334 will receive score 0.
# Unanswered question uit_022521 will receive score 0.
# Unanswered question uit_025966 will receive score 0.
# Unanswered question uit_028128 will receive score 0.
# Unanswered question uit_005408 will receive score 0.
# Unanswered question uit_023718 will receive score 0.
# Unanswered question uit_011939 will receive score 0.
# Unanswered question uit_011034 will receive score 0.
# Unanswered question uit_008537 will receive score 0.
# Unanswered question uit_026851 will receive score 0.
# Unanswered question uit_008091 will receive score 0.
# Unanswered question uit_001378 will receive score 0.
# Unanswered question uit_018749 will receive score 0.
# Unanswered question uit_018953 will receive score 0.
# Unanswered question uit_015883 will receive score 0.
# Unanswered question uit_001595 will receive score 0.
# Unanswered question uit_025088 will receive score 0.
# Unanswered question uit_004601 will receive score 0.
# Unanswered question uit_028228 will receive score 0.
# Unanswered question uit_003559 will receive score 0.
# Unanswered question uit_017720 will receive score 0.
# Unanswered question uit_022858 will receive score 0.
# Unanswered question uit_004804 will receive score 0.
# Unanswered question uit_008978 will receive score 0.
# Unanswered question uit_010887 will receive score 0.
# Unanswered question uit_016667 will receive score 0.
# Unanswered question uit_008852 will receive score 0.
# Unanswered question uit_005399 will receive score 0.
# Unanswered question uit_019589 will receive score 0.
# Unanswered question uit_024569 will receive score 0.
# Unanswered question uit_012713 will receive score 0.
# Unanswered question uit_002526 will receive score 0.
# Unanswered question uit_000261 will receive score 0.
# Unanswered question uit_024891 will receive score 0.
# Unanswered question uit_020461 will receive score 0.
# Unanswered question uit_011331 will receive score 0.
# Unanswered question uit_023504 will receive score 0.
# Unanswered question uit_004396 will receive score 0.
# Unanswered question uit_027638 will receive score 0.
# Unanswered question uit_022693 will receive score 0.
# Unanswered question uit_011785 will receive score 0.
# Unanswered question uit_011022 will receive score 0.
# Unanswered question uit_015612 will receive score 0.
# Unanswered question uit_019278 will receive score 0.
# Unanswered question uit_027995 will receive score 0.
# Unanswered question uit_023320 will receive score 0.
# Unanswered question uit_011755 will receive score 0.
# Unanswered question uit_026907 will receive score 0.
# Unanswered question uit_011508 will receive score 0.
# Unanswered question uit_028142 will receive score 0.
# Unanswered question uit_006771 will receive score 0.
# Unanswered question uit_027222 will receive score 0.
# Unanswered question uit_011080 will receive score 0.
# Unanswered question uit_007450 will receive score 0.
# Unanswered question uit_015544 will receive score 0.
# Unanswered question uit_024073 will receive score 0.
# Unanswered question uit_023374 will receive score 0.
# Unanswered question uit_026022 will receive score 0.
# Unanswered question uit_005308 will receive score 0.
# Unanswered question uit_008397 will receive score 0.
# Unanswered question uit_002907 will receive score 0.
# Unanswered question uit_017474 will receive score 0.
# Unanswered question uit_003490 will receive score 0.
# Unanswered question uit_008124 will receive score 0.
# Unanswered question uit_011067 will receive score 0.
# Unanswered question uit_004881 will receive score 0.
# Unanswered question uit_007333 will receive score 0.
# Unanswered question uit_010750 will receive score 0.
# Unanswered question uit_020131 will receive score 0.
# Unanswered question uit_003585 will receive score 0.
# Unanswered question uit_011484 will receive score 0.
# Unanswered question uit_015102 will receive score 0.
# Unanswered question uit_002091 will receive score 0.
# Unanswered question uit_022287 will receive score 0.
# Unanswered question uit_028432 will receive score 0.
# Unanswered question uit_018393 will receive score 0.
# Unanswered question uit_023753 will receive score 0.
# Unanswered question uit_014215 will receive score 0.
# Unanswered question uit_009449 will receive score 0.
# Unanswered question uit_024002 will receive score 0.
# Unanswered question uit_000556 will receive score 0.
# Unanswered question uit_026443 will receive score 0.
# Unanswered question uit_004640 will receive score 0.
# Unanswered question uit_024142 will receive score 0.
# Unanswered question uit_011167 will receive score 0.
# Unanswered question uit_002025 will receive score 0.
# Unanswered question uit_027061 will receive score 0.
# Unanswered question uit_024771 will receive score 0.
# Unanswered question uit_015150 will receive score 0.
# Unanswered question uit_000866 will receive score 0.
# Unanswered question uit_016369 will receive score 0.
# Unanswered question uit_023241 will receive score 0.
# Unanswered question uit_006819 will receive score 0.
# Unanswered question uit_013849 will receive score 0.
# Unanswered question uit_022809 will receive score 0.
# Unanswered question uit_014506 will receive score 0.
# Unanswered question uit_018707 will receive score 0.
# Unanswered question uit_024086 will receive score 0.
# Unanswered question uit_006367 will receive score 0.
# Unanswered question uit_018774 will receive score 0.
# Unanswered question uit_001493 will receive score 0.
# Unanswered question uit_007237 will receive score 0.
# Unanswered question uit_017658 will receive score 0.
# Unanswered question uit_023729 will receive score 0.
# Unanswered question uit_020653 will receive score 0.
# Unanswered question uit_016870 will receive score 0.
# Unanswered question uit_007409 will receive score 0.
# Unanswered question uit_027105 will receive score 0.
# Unanswered question uit_025238 will receive score 0.
# Unanswered question uit_027238 will receive score 0.
# Unanswered question uit_015098 will receive score 0.
# Unanswered question uit_013154 will receive score 0.
# Unanswered question uit_013812 will receive score 0.
# Unanswered question uit_022147 will receive score 0.
# Unanswered question uit_018884 will receive score 0.
# Unanswered question uit_023957 will receive score 0.
# Unanswered question uit_027052 will receive score 0.
# Unanswered question uit_003349 will receive score 0.
# Unanswered question uit_023454 will receive score 0.
# Unanswered question uit_024719 will receive score 0.
# Unanswered question uit_023324 will receive score 0.
# Unanswered question uit_015231 will receive score 0.
# Unanswered question uit_007880 will receive score 0.
# Unanswered question uit_027675 will receive score 0.
# Unanswered question uit_026877 will receive score 0.
# Unanswered question uit_027529 will receive score 0.
# Unanswered question uit_007569 will receive score 0.
# Unanswered question uit_001930 will receive score 0.
# Unanswered question uit_009734 will receive score 0.
# Unanswered question uit_020493 will receive score 0.
# Unanswered question uit_012429 will receive score 0.
# Unanswered question uit_018751 will receive score 0.
# Unanswered question uit_020298 will receive score 0.
# Unanswered question uit_003951 will receive score 0.
# Unanswered question uit_002088 will receive score 0.
# Unanswered question uit_026973 will receive score 0.
# Unanswered question uit_028131 will receive score 0.
# Unanswered question uit_018536 will receive score 0.
# Unanswered question uit_027687 will receive score 0.
# Unanswered question uit_014077 will receive score 0.
# Unanswered question uit_011807 will receive score 0.
# Unanswered question uit_005587 will receive score 0.
# Unanswered question uit_000891 will receive score 0.
# Unanswered question uit_000401 will receive score 0.
# Unanswered question uit_008100 will receive score 0.
# Unanswered question uit_025616 will receive score 0.
# Unanswered question uit_009459 will receive score 0.
# Unanswered question uit_019576 will receive score 0.
# Unanswered question uit_016721 will receive score 0.
# Unanswered question uit_012988 will receive score 0.
# Unanswered question uit_002147 will receive score 0.
# Unanswered question uit_003135 will receive score 0.
# Unanswered question uit_027223 will receive score 0.
# Unanswered question uit_003447 will receive score 0.
# Unanswered question uit_021615 will receive score 0.
# Unanswered question uit_022635 will receive score 0.
# Unanswered question uit_006933 will receive score 0.
# Unanswered question uit_010679 will receive score 0.
# Unanswered question uit_000727 will receive score 0.
# Unanswered question uit_021264 will receive score 0.
# Unanswered question uit_008512 will receive score 0.
# Unanswered question uit_016714 will receive score 0.
# Unanswered question uit_016643 will receive score 0.
# Unanswered question uit_005020 will receive score 0.
# Unanswered question uit_026048 will receive score 0.
# Unanswered question uit_005321 will receive score 0.
# Unanswered question uit_000090 will receive score 0.
# Unanswered question uit_000428 will receive score 0.
# Unanswered question uit_025159 will receive score 0.
# Unanswered question uit_013306 will receive score 0.
# Unanswered question uit_005142 will receive score 0.
# Unanswered question uit_028183 will receive score 0.
# Unanswered question uit_027122 will receive score 0.
# Unanswered question uit_005679 will receive score 0.
# Unanswered question uit_022735 will receive score 0.
# Unanswered question uit_026364 will receive score 0.
# Unanswered question uit_020294 will receive score 0.
# Unanswered question uit_016248 will receive score 0.
# Unanswered question uit_005707 will receive score 0.
# Unanswered question uit_013901 will receive score 0.
# Unanswered question uit_022415 will receive score 0.
# Unanswered question uit_026402 will receive score 0.
# Unanswered question uit_008755 will receive score 0.
# Unanswered question uit_026166 will receive score 0.
# Unanswered question uit_020915 will receive score 0.
# Unanswered question uit_006983 will receive score 0.
# Unanswered question uit_012157 will receive score 0.
# Unanswered question uit_007743 will receive score 0.
# Unanswered question uit_000143 will receive score 0.
# Unanswered question uit_009778 will receive score 0.
# Unanswered question uit_006320 will receive score 0.
# Unanswered question uit_016538 will receive score 0.
# Unanswered question uit_008696 will receive score 0.
# Unanswered question uit_005541 will receive score 0.
# Unanswered question uit_002631 will receive score 0.
# Unanswered question uit_020524 will receive score 0.
# Unanswered question uit_019530 will receive score 0.
# Unanswered question uit_011956 will receive score 0.
# Unanswered question uit_015912 will receive score 0.
# Unanswered question uit_015461 will receive score 0.
# Unanswered question uit_007970 will receive score 0.
# Unanswered question uit_004036 will receive score 0.
# Unanswered question uit_024338 will receive score 0.
# Unanswered question uit_007139 will receive score 0.
# Unanswered question uit_021132 will receive score 0.
# Unanswered question uit_027080 will receive score 0.
# Unanswered question uit_002223 will receive score 0.
# Unanswered question uit_010801 will receive score 0.
# Unanswered question uit_010459 will receive score 0.
# Unanswered question uit_018533 will receive score 0.
# Unanswered question uit_019807 will receive score 0.
# Unanswered question uit_012407 will receive score 0.
# Unanswered question uit_009819 will receive score 0.
# Unanswered question uit_009110 will receive score 0.
# Unanswered question uit_002511 will receive score 0.
# Unanswered question uit_007338 will receive score 0.
# Unanswered question uit_016192 will receive score 0.
# Unanswered question uit_017593 will receive score 0.
# Unanswered question uit_000327 will receive score 0.
# Unanswered question uit_022016 will receive score 0.
# Unanswered question uit_009233 will receive score 0.
# Unanswered question uit_012886 will receive score 0.
# Unanswered question uit_027037 will receive score 0.
# Unanswered question uit_027354 will receive score 0.
# Unanswered question uit_003005 will receive score 0.
# Unanswered question uit_004032 will receive score 0.
# Unanswered question uit_020988 will receive score 0.
# Unanswered question uit_013652 will receive score 0.
# Unanswered question uit_004838 will receive score 0.
# Unanswered question uit_022746 will receive score 0.
# Unanswered question uit_010847 will receive score 0.
# Unanswered question uit_014632 will receive score 0.
# Unanswered question uit_004969 will receive score 0.
# Unanswered question uit_002908 will receive score 0.
# Unanswered question uit_011332 will receive score 0.
# Unanswered question uit_020878 will receive score 0.
# Unanswered question uit_025943 will receive score 0.
# Unanswered question uit_019308 will receive score 0.
# Unanswered question uit_013345 will receive score 0.
# Unanswered question uit_005694 will receive score 0.
# Unanswered question uit_011438 will receive score 0.
# Unanswered question uit_006398 will receive score 0.
# Unanswered question uit_014185 will receive score 0.
# Unanswered question uit_014686 will receive score 0.
# Unanswered question uit_025247 will receive score 0.
# Unanswered question uit_001621 will receive score 0.
# Unanswered question uit_021437 will receive score 0.
# Unanswered question uit_018862 will receive score 0.
# Unanswered question uit_020574 will receive score 0.
# Unanswered question uit_002250 will receive score 0.
# Unanswered question uit_007364 will receive score 0.
# Unanswered question uit_007844 will receive score 0.
# Unanswered question uit_016172 will receive score 0.
# Unanswered question uit_018822 will receive score 0.
# Unanswered question uit_012171 will receive score 0.
# Unanswered question uit_013765 will receive score 0.
# Unanswered question uit_028234 will receive score 0.
# Unanswered question uit_004672 will receive score 0.
# Unanswered question uit_014244 will receive score 0.
# Unanswered question uit_001613 will receive score 0.
# Unanswered question uit_021978 will receive score 0.
# Unanswered question uit_018180 will receive score 0.
# Unanswered question uit_010464 will receive score 0.
# Unanswered question uit_022588 will receive score 0.
# Unanswered question uit_012569 will receive score 0.
# Unanswered question uit_002156 will receive score 0.
# Unanswered question uit_027088 will receive score 0.
# Unanswered question uit_023841 will receive score 0.
# Unanswered question uit_027567 will receive score 0.
# Unanswered question uit_027031 will receive score 0.
# Unanswered question uit_025180 will receive score 0.
# Unanswered question uit_013470 will receive score 0.
# Unanswered question uit_012320 will receive score 0.
# Unanswered question uit_007328 will receive score 0.
# Unanswered question uit_010223 will receive score 0.
# Unanswered question uit_025004 will receive score 0.
# Unanswered question uit_019781 will receive score 0.
# Unanswered question uit_003729 will receive score 0.
# Unanswered question uit_015969 will receive score 0.
# Unanswered question uit_005505 will receive score 0.
# Unanswered question uit_011518 will receive score 0.
# Unanswered question uit_013458 will receive score 0.
# Unanswered question uit_022271 will receive score 0.
# Unanswered question uit_009526 will receive score 0.
# Unanswered question uit_014317 will receive score 0.
# Unanswered question uit_005371 will receive score 0.
# Unanswered question uit_012452 will receive score 0.
# Unanswered question uit_026491 will receive score 0.
# Unanswered question uit_002639 will receive score 0.
# Unanswered question uit_011499 will receive score 0.
# Unanswered question uit_020836 will receive score 0.
# Unanswered question uit_019285 will receive score 0.
# Unanswered question uit_013037 will receive score 0.
# Unanswered question uit_019271 will receive score 0.
# Unanswered question uit_019980 will receive score 0.
# Unanswered question uit_005114 will receive score 0.
# Unanswered question uit_018418 will receive score 0.
# Unanswered question uit_008955 will receive score 0.
# Unanswered question uit_011099 will receive score 0.
# Unanswered question uit_014644 will receive score 0.
# Unanswered question uit_027397 will receive score 0.
# Unanswered question uit_000385 will receive score 0.
# Unanswered question uit_014929 will receive score 0.
# Unanswered question uit_014548 will receive score 0.
# Unanswered question uit_027620 will receive score 0.
# Unanswered question uit_008450 will receive score 0.
# Unanswered question uit_014786 will receive score 0.
# Unanswered question uit_011737 will receive score 0.
# Unanswered question uit_017626 will receive score 0.
# Unanswered question uit_003209 will receive score 0.
# Unanswered question uit_017880 will receive score 0.
# Unanswered question uit_016798 will receive score 0.
# Unanswered question uit_002327 will receive score 0.
# Unanswered question uit_010113 will receive score 0.
# Unanswered question uit_009854 will receive score 0.
# Unanswered question uit_000426 will receive score 0.
# Unanswered question uit_021795 will receive score 0.
# Unanswered question uit_016518 will receive score 0.
# Unanswered question uit_028298 will receive score 0.
# Unanswered question uit_017955 will receive score 0.
# Unanswered question uit_028442 will receive score 0.
# Unanswered question uit_000497 will receive score 0.
# Unanswered question uit_007979 will receive score 0.
# Unanswered question uit_014258 will receive score 0.
# Unanswered question uit_011748 will receive score 0.
# Unanswered question uit_027975 will receive score 0.
# Unanswered question uit_012844 will receive score 0.
# Unanswered question uit_020677 will receive score 0.
# Unanswered question uit_008861 will receive score 0.
# Unanswered question uit_012363 will receive score 0.
# Unanswered question uit_000611 will receive score 0.
# Unanswered question uit_014567 will receive score 0.
# Unanswered question uit_014170 will receive score 0.
# Unanswered question uit_009083 will receive score 0.
# Unanswered question uit_025983 will receive score 0.
# Unanswered question uit_008531 will receive score 0.
# Unanswered question uit_015048 will receive score 0.
# Unanswered question uit_006802 will receive score 0.
# Unanswered question uit_000159 will receive score 0.
# Unanswered question uit_003431 will receive score 0.
# Unanswered question uit_016533 will receive score 0.
# Unanswered question uit_010151 will receive score 0.
# Unanswered question uit_002172 will receive score 0.
# Unanswered question uit_001545 will receive score 0.
# Unanswered question uit_015962 will receive score 0.
# Unanswered question uit_019211 will receive score 0.
# Unanswered question uit_023888 will receive score 0.
# Unanswered question uit_009089 will receive score 0.
# Unanswered question uit_017574 will receive score 0.
# Unanswered question uit_026214 will receive score 0.
# Unanswered question uit_000425 will receive score 0.
# Unanswered question uit_025603 will receive score 0.
# Unanswered question uit_010958 will receive score 0.
# Unanswered question uit_021565 will receive score 0.
# Unanswered question uit_027038 will receive score 0.
# Unanswered question uit_022127 will receive score 0.
# Unanswered question uit_019167 will receive score 0.
# Unanswered question uit_007118 will receive score 0.
# Unanswered question uit_002407 will receive score 0.
# Unanswered question uit_014680 will receive score 0.
# Unanswered question uit_012961 will receive score 0.
# Unanswered question uit_006188 will receive score 0.
# Unanswered question uit_023014 will receive score 0.
# Unanswered question uit_002938 will receive score 0.
# Unanswered question uit_026546 will receive score 0.
# Unanswered question uit_021201 will receive score 0.
# Unanswered question uit_016166 will receive score 0.
# Unanswered question uit_010247 will receive score 0.
# Unanswered question uit_006018 will receive score 0.
# Unanswered question uit_014957 will receive score 0.
# Unanswered question uit_006002 will receive score 0.
# Unanswered question uit_021517 will receive score 0.
# Unanswered question uit_009795 will receive score 0.
# Unanswered question uit_009286 will receive score 0.
# Unanswered question uit_021542 will receive score 0.
# Unanswered question uit_027545 will receive score 0.
# Unanswered question uit_004158 will receive score 0.
# Unanswered question uit_015074 will receive score 0.
# Unanswered question uit_009735 will receive score 0.
# Unanswered question uit_023048 will receive score 0.
# Unanswered question uit_006475 will receive score 0.
# Unanswered question uit_004364 will receive score 0.
# Unanswered question uit_015216 will receive score 0.
# Unanswered question uit_003111 will receive score 0.
# Unanswered question uit_004340 will receive score 0.
# Unanswered question uit_014911 will receive score 0.
# Unanswered question uit_021844 will receive score 0.
# Unanswered question uit_006422 will receive score 0.
# Unanswered question uit_014456 will receive score 0.
# Unanswered question uit_001269 will receive score 0.
# Unanswered question uit_011955 will receive score 0.
# Unanswered question uit_003767 will receive score 0.
# Unanswered question uit_015564 will receive score 0.
# Unanswered question uit_009106 will receive score 0.
# Unanswered question uit_002649 will receive score 0.
# Unanswered question uit_015178 will receive score 0.
# Unanswered question uit_023193 will receive score 0.
# Unanswered question uit_006733 will receive score 0.
# Unanswered question uit_007085 will receive score 0.
# Unanswered question uit_010964 will receive score 0.
# Unanswered question uit_007692 will receive score 0.
# Unanswered question uit_014704 will receive score 0.
# Unanswered question uit_012165 will receive score 0.
# Unanswered question uit_025748 will receive score 0.
# Unanswered question uit_026074 will receive score 0.
# Unanswered question uit_000100 will receive score 0.
# Unanswered question uit_015938 will receive score 0.
# Unanswered question uit_027139 will receive score 0.
# Unanswered question uit_024098 will receive score 0.
# Unanswered question uit_016537 will receive score 0.
# Unanswered question uit_028280 will receive score 0.
# Unanswered question uit_020569 will receive score 0.
# Unanswered question uit_009715 will receive score 0.
# Unanswered question uit_021053 will receive score 0.
# Unanswered question uit_013230 will receive score 0.
# Unanswered question uit_004710 will receive score 0.
# Unanswered question uit_001608 will receive score 0.
# Unanswered question uit_009559 will receive score 0.
# Unanswered question uit_005434 will receive score 0.
# Unanswered question uit_027179 will receive score 0.
# Unanswered question uit_016754 will receive score 0.
# Unanswered question uit_019637 will receive score 0.
# Unanswered question uit_022528 will receive score 0.
# Unanswered question uit_009448 will receive score 0.
# Unanswered question uit_003616 will receive score 0.
# Unanswered question uit_024724 will receive score 0.
# Unanswered question uit_027190 will receive score 0.
# Unanswered question uit_023698 will receive score 0.
# Unanswered question uit_027098 will receive score 0.
# Unanswered question uit_006305 will receive score 0.
# Unanswered question uit_027181 will receive score 0.
# Unanswered question uit_013743 will receive score 0.
# Unanswered question uit_023244 will receive score 0.
# Unanswered question uit_017385 will receive score 0.
# Unanswered question uit_027279 will receive score 0.
# Unanswered question uit_012449 will receive score 0.
# Unanswered question uit_018754 will receive score 0.
# Unanswered question uit_018077 will receive score 0.
# Unanswered question uit_027340 will receive score 0.
# Unanswered question uit_014824 will receive score 0.
# Unanswered question uit_025133 will receive score 0.
# Unanswered question uit_027249 will receive score 0.
# Unanswered question uit_017045 will receive score 0.
# Unanswered question uit_010907 will receive score 0.
# Unanswered question uit_025525 will receive score 0.
# Unanswered question uit_000692 will receive score 0.
# Unanswered question uit_027780 will receive score 0.
# Unanswered question uit_004353 will receive score 0.
# Unanswered question uit_000636 will receive score 0.
# Unanswered question uit_022392 will receive score 0.
# Unanswered question uit_018392 will receive score 0.
# Unanswered question uit_013942 will receive score 0.
# Unanswered question uit_000151 will receive score 0.
# Unanswered question uit_023791 will receive score 0.
# Unanswered question uit_025181 will receive score 0.
# Unanswered question uit_022747 will receive score 0.
# Unanswered question uit_018166 will receive score 0.
# Unanswered question uit_020259 will receive score 0.
# Unanswered question uit_014440 will receive score 0.
# Unanswered question uit_004741 will receive score 0.
# Unanswered question uit_013795 will receive score 0.
# Unanswered question uit_021158 will receive score 0.
# Unanswered question uit_002369 will receive score 0.
# Unanswered question uit_027952 will receive score 0.
# Unanswered question uit_026037 will receive score 0.
# Unanswered question uit_002930 will receive score 0.
# Unanswered question uit_007672 will receive score 0.
# Unanswered question uit_013846 will receive score 0.
# Unanswered question uit_010656 will receive score 0.
# Unanswered question uit_016663 will receive score 0.
# Unanswered question uit_007774 will receive score 0.
# Unanswered question uit_003394 will receive score 0.
# Unanswered question uit_000005 will receive score 0.
# Unanswered question uit_000270 will receive score 0.
# Unanswered question uit_015865 will receive score 0.
# Unanswered question uit_018000 will receive score 0.
# Unanswered question uit_023757 will receive score 0.
# Unanswered question uit_006965 will receive score 0.
# Unanswered question uit_011653 will receive score 0.
# Unanswered question uit_009379 will receive score 0.
# Unanswered question uit_006769 will receive score 0.
# Unanswered question uit_017555 will receive score 0.
# Unanswered question uit_027707 will receive score 0.
# Unanswered question uit_014656 will receive score 0.
# Unanswered question uit_016310 will receive score 0.
# Unanswered question uit_019240 will receive score 0.
# Unanswered question uit_022857 will receive score 0.
# Unanswered question uit_020723 will receive score 0.
# Unanswered question uit_018001 will receive score 0.
# Unanswered question uit_022083 will receive score 0.
# Unanswered question uit_016933 will receive score 0.
# Unanswered question uit_009685 will receive score 0.
# Unanswered question uit_006896 will receive score 0.
# Unanswered question uit_003618 will receive score 0.
# Unanswered question uit_007455 will receive score 0.
# Unanswered question uit_006261 will receive score 0.
# Unanswered question uit_003724 will receive score 0.
# Unanswered question uit_024992 will receive score 0.
# Unanswered question uit_020119 will receive score 0.
# Unanswered question uit_017168 will receive score 0.
# Unanswered question uit_005683 will receive score 0.
# Unanswered question uit_008411 will receive score 0.
# Unanswered question uit_008784 will receive score 0.
# Unanswered question uit_016818 will receive score 0.
# Unanswered question uit_022771 will receive score 0.
# Unanswered question uit_019244 will receive score 0.
# Unanswered question uit_011539 will receive score 0.
# Unanswered question uit_026943 will receive score 0.
# Unanswered question uit_016800 will receive score 0.
# Unanswered question uit_003029 will receive score 0.
# Unanswered question uit_014535 will receive score 0.
# Unanswered question uit_021325 will receive score 0.
# Unanswered question uit_027732 will receive score 0.
# Unanswered question uit_003756 will receive score 0.
# Unanswered question uit_022074 will receive score 0.
# Unanswered question uit_027280 will receive score 0.
# Unanswered question uit_027503 will receive score 0.
# Unanswered question uit_000179 will receive score 0.
# Unanswered question uit_015519 will receive score 0.
# Unanswered question uit_018430 will receive score 0.
# Unanswered question uit_002467 will receive score 0.
# Unanswered question uit_027383 will receive score 0.
# Unanswered question uit_003073 will receive score 0.
# Unanswered question uit_017613 will receive score 0.
# Unanswered question uit_012863 will receive score 0.
# Unanswered question uit_001717 will receive score 0.
# Unanswered question uit_014246 will receive score 0.
# Unanswered question uit_010237 will receive score 0.
# Unanswered question uit_021225 will receive score 0.
# Unanswered question uit_004474 will receive score 0.
# Unanswered question uit_023155 will receive score 0.
# Unanswered question uit_005540 will receive score 0.
# Unanswered question uit_014999 will receive score 0.
# Unanswered question uit_026861 will receive score 0.
# Unanswered question uit_010285 will receive score 0.
# Unanswered question uit_000917 will receive score 0.
# Unanswered question uit_023605 will receive score 0.
# Unanswered question uit_000345 will receive score 0.
# Unanswered question uit_000688 will receive score 0.
# Unanswered question uit_009516 will receive score 0.
# Unanswered question uit_002739 will receive score 0.
# Unanswered question uit_008837 will receive score 0.
# Unanswered question uit_004573 will receive score 0.
# Unanswered question uit_002881 will receive score 0.
# Unanswered question uit_027510 will receive score 0.
# Unanswered question uit_018214 will receive score 0.
# Unanswered question uit_001599 will receive score 0.
# Unanswered question uit_010582 will receive score 0.
# Unanswered question uit_007137 will receive score 0.
# Unanswered question uit_000502 will receive score 0.
# Unanswered question uit_000416 will receive score 0.
# Unanswered question uit_023260 will receive score 0.
# Unanswered question uit_006039 will receive score 0.
# Unanswered question uit_022273 will receive score 0.
# Unanswered question uit_026697 will receive score 0.
# Unanswered question uit_006559 will receive score 0.
# Unanswered question uit_020825 will receive score 0.
# Unanswered question uit_019988 will receive score 0.
# Unanswered question uit_003076 will receive score 0.
# Unanswered question uit_011137 will receive score 0.
# Unanswered question uit_018854 will receive score 0.
# Unanswered question uit_016514 will receive score 0.
# Unanswered question uit_007010 will receive score 0.
# Unanswered question uit_016041 will receive score 0.
# Unanswered question uit_004056 will receive score 0.
# Unanswered question uit_026746 will receive score 0.
# Unanswered question uit_012068 will receive score 0.
# Unanswered question uit_021136 will receive score 0.
# Unanswered question uit_027472 will receive score 0.
# Unanswered question uit_002050 will receive score 0.
# Unanswered question uit_019068 will receive score 0.
# Unanswered question uit_028340 will receive score 0.
# Unanswered question uit_001705 will receive score 0.
# Unanswered question uit_014536 will receive score 0.
# Unanswered question uit_010060 will receive score 0.
# Unanswered question uit_014022 will receive score 0.
# Unanswered question uit_026759 will receive score 0.
# Unanswered question uit_011452 will receive score 0.
# Unanswered question uit_007297 will receive score 0.
# Unanswered question uit_025984 will receive score 0.
# Unanswered question uit_003537 will receive score 0.
# Unanswered question uit_015189 will receive score 0.
# Unanswered question uit_006459 will receive score 0.
# Unanswered question uit_006094 will receive score 0.
# Unanswered question uit_005359 will receive score 0.
# Unanswered question uit_018177 will receive score 0.
# Unanswered question uit_000887 will receive score 0.
# Unanswered question uit_001367 will receive score 0.
# Unanswered question uit_018860 will receive score 0.
# Unanswered question uit_001959 will receive score 0.
# Unanswered question uit_019646 will receive score 0.
# Unanswered question uit_022388 will receive score 0.
# Unanswered question uit_014861 will receive score 0.
# Unanswered question uit_004830 will receive score 0.
# Unanswered question uit_005582 will receive score 0.
# Unanswered question uit_001961 will receive score 0.
# Unanswered question uit_013843 will receive score 0.
# Unanswered question uit_007610 will receive score 0.
# Unanswered question uit_001570 will receive score 0.
# Unanswered question uit_008272 will receive score 0.
# Unanswered question uit_006025 will receive score 0.
# Unanswered question uit_014279 will receive score 0.
# Unanswered question uit_000739 will receive score 0.
# Unanswered question uit_010667 will receive score 0.
# Unanswered question uit_014457 will receive score 0.
# Unanswered question uit_027621 will receive score 0.
# Unanswered question uit_024899 will receive score 0.
# Unanswered question uit_025035 will receive score 0.
# Unanswered question uit_017719 will receive score 0.
# Unanswered question uit_001954 will receive score 0.
# Unanswered question uit_002421 will receive score 0.
# Unanswered question uit_004194 will receive score 0.
# Unanswered question uit_024194 will receive score 0.
# Unanswered question uit_005159 will receive score 0.
# Unanswered question uit_007737 will receive score 0.
# Unanswered question uit_010101 will receive score 0.
# Unanswered question uit_015610 will receive score 0.
# Unanswered question uit_010416 will receive score 0.
# Unanswered question uit_011813 will receive score 0.
# Unanswered question uit_025301 will receive score 0.
# Unanswered question uit_005818 will receive score 0.
# Unanswered question uit_000152 will receive score 0.
# Unanswered question uit_012653 will receive score 0.
# Unanswered question uit_000314 will receive score 0.
# Unanswered question uit_009561 will receive score 0.
# Unanswered question uit_012417 will receive score 0.
# Unanswered question uit_015832 will receive score 0.
# Unanswered question uit_025000 will receive score 0.
# Unanswered question uit_025165 will receive score 0.
# Unanswered question uit_012586 will receive score 0.
# Unanswered question uit_025394 will receive score 0.
# Unanswered question uit_018039 will receive score 0.
# Unanswered question uit_012761 will receive score 0.
# Unanswered question uit_015804 will receive score 0.
# Unanswered question uit_003095 will receive score 0.
# Unanswered question uit_000928 will receive score 0.
# Unanswered question uit_002898 will receive score 0.
# Unanswered question uit_014084 will receive score 0.
# Unanswered question uit_003179 will receive score 0.
# Unanswered question uit_026762 will receive score 0.
# Unanswered question uit_011141 will receive score 0.
# Unanswered question uit_016441 will receive score 0.
# Unanswered question uit_008218 will receive score 0.
# Unanswered question uit_027886 will receive score 0.
# Unanswered question uit_027175 will receive score 0.
# Unanswered question uit_022433 will receive score 0.
# Unanswered question uit_010711 will receive score 0.
# Unanswered question uit_000461 will receive score 0.
# Unanswered question uit_000148 will receive score 0.
# Unanswered question uit_026327 will receive score 0.
# Unanswered question uit_023972 will receive score 0.
# Unanswered question uit_021046 will receive score 0.
# Unanswered question uit_004721 will receive score 0.
# Unanswered question uit_024617 will receive score 0.
# Unanswered question uit_027610 will receive score 0.
# Unanswered question uit_024990 will receive score 0.
# Unanswered question uit_000390 will receive score 0.
# Unanswered question uit_010963 will receive score 0.
# Unanswered question uit_015960 will receive score 0.
# Unanswered question uit_015335 will receive score 0.
# Unanswered question uit_018522 will receive score 0.
# Unanswered question uit_011864 will receive score 0.
# Unanswered question uit_022500 will receive score 0.
# Unanswered question uit_005189 will receive score 0.
# Unanswered question uit_006939 will receive score 0.
# Unanswered question uit_022295 will receive score 0.
# Unanswered question uit_023070 will receive score 0.
# Unanswered question uit_008727 will receive score 0.
# Unanswered question uit_014579 will receive score 0.
# Unanswered question uit_013702 will receive score 0.
# Unanswered question uit_000697 will receive score 0.
# Unanswered question uit_013505 will receive score 0.
# Unanswered question uit_018291 will receive score 0.
# Unanswered question uit_021290 will receive score 0.
# Unanswered question uit_001702 will receive score 0.
# Unanswered question uit_000235 will receive score 0.
# Unanswered question uit_012217 will receive score 0.
# Unanswered question uit_006109 will receive score 0.
# Unanswered question uit_004771 will receive score 0.
# Unanswered question uit_003703 will receive score 0.
# Unanswered question uit_020378 will receive score 0.
# Unanswered question uit_008949 will receive score 0.
# Unanswered question uit_008202 will receive score 0.
# Unanswered question uit_003071 will receive score 0.
# Unanswered question uit_013059 will receive score 0.
# Unanswered question uit_009493 will receive score 0.
# Unanswered question uit_026308 will receive score 0.
# Unanswered question uit_022941 will receive score 0.
# Unanswered question uit_004137 will receive score 0.
# Unanswered question uit_012939 will receive score 0.
# Unanswered question uit_012037 will receive score 0.
# Unanswered question uit_021921 will receive score 0.
# Unanswered question uit_020098 will receive score 0.
# Unanswered question uit_013719 will receive score 0.
# Unanswered question uit_027242 will receive score 0.
# Unanswered question uit_016258 will receive score 0.
# Unanswered question uit_024510 will receive score 0.
# Unanswered question uit_023894 will receive score 0.
# Unanswered question uit_008050 will receive score 0.
# Unanswered question uit_025477 will receive score 0.
# Unanswered question uit_004379 will receive score 0.
# Unanswered question uit_009253 will receive score 0.
# Unanswered question uit_011316 will receive score 0.
# Unanswered question uit_004256 will receive score 0.
# Unanswered question uit_024340 will receive score 0.
# Unanswered question uit_025112 will receive score 0.
# Unanswered question uit_019331 will receive score 0.
# Unanswered question uit_023214 will receive score 0.
# Unanswered question uit_008921 will receive score 0.
# Unanswered question uit_024560 will receive score 0.
# Unanswered question uit_011943 will receive score 0.
# Unanswered question uit_002743 will receive score 0.
# Unanswered question uit_007714 will receive score 0.
# Unanswered question uit_008059 will receive score 0.
# Unanswered question uit_021929 will receive score 0.
# Unanswered question uit_019762 will receive score 0.
# Unanswered question uit_027927 will receive score 0.
# Unanswered question uit_006015 will receive score 0.
# Unanswered question uit_018986 will receive score 0.
# Unanswered question uit_025143 will receive score 0.
# Unanswered question uit_005115 will receive score 0.
# Unanswered question uit_024563 will receive score 0.
# Unanswered question uit_007755 will receive score 0.
# Unanswered question uit_009691 will receive score 0.
# Unanswered question uit_026102 will receive score 0.
# Unanswered question uit_017248 will receive score 0.
# Unanswered question uit_005522 will receive score 0.
# Unanswered question uit_015236 will receive score 0.
# Unanswered question uit_010608 will receive score 0.
# Unanswered question uit_027266 will receive score 0.
# Unanswered question uit_025997 will receive score 0.
# Unanswered question uit_015428 will receive score 0.
# Unanswered question uit_001982 will receive score 0.
# Unanswered question uit_006179 will receive score 0.
# Unanswered question uit_003636 will receive score 0.
# Unanswered question uit_001775 will receive score 0.
# Unanswered question uit_026784 will receive score 0.
# Unanswered question uit_025092 will receive score 0.
# Unanswered question uit_003888 will receive score 0.
# Unanswered question uit_014118 will receive score 0.
# Unanswered question uit_010339 will receive score 0.
# Unanswered question uit_008410 will receive score 0.
# Unanswered question uit_019621 will receive score 0.
# Unanswered question uit_010879 will receive score 0.
# Unanswered question uit_017404 will receive score 0.
# Unanswered question uit_009604 will receive score 0.
# Unanswered question uit_020108 will receive score 0.
# Unanswered question uit_007565 will receive score 0.
# Unanswered question uit_003477 will receive score 0.
# Unanswered question uit_024902 will receive score 0.
# Unanswered question uit_003455 will receive score 0.
# Unanswered question uit_008437 will receive score 0.
# Unanswered question uit_015124 will receive score 0.
# Unanswered question uit_010167 will receive score 0.
# Unanswered question uit_002252 will receive score 0.
# Unanswered question uit_019855 will receive score 0.
# Unanswered question uit_004438 will receive score 0.
# Unanswered question uit_010706 will receive score 0.
# Unanswered question uit_003582 will receive score 0.
# Unanswered question uit_013503 will receive score 0.
# Unanswered question uit_026536 will receive score 0.
# Unanswered question uit_020529 will receive score 0.
# ...
# Unanswered question uit_018295 will receive score 0.
# Unanswered question uit_005189 will receive score 0.
# Unanswered question uit_022295 will receive score 0.
# Unanswered question uit_015523 will receive score 0.
# Unanswered question uit_020028 will receive score 0.
# Unanswered question uit_023070 will receive score 0.
# Unanswered question uit_021064 will receive score 0.
# Unanswered question uit_008727 will receive score 0.
# Unanswered question uit_013702 will receive score 0.
# Unanswered question uit_000697 will receive score 0.
# Unanswered question uit_011529 will receive score 0.
# Unanswered question uit_021290 will receive score 0.
# Unanswered question uit_001702 will receive score 0.
# Unanswered question uit_001655 will receive score 0.
# Unanswered question uit_012217 will receive score 0.
# Unanswered question uit_004771 will receive score 0.
# Unanswered question uit_003703 will receive score 0.
# Unanswered question uit_009814 will receive score 0.
# Unanswered question uit_005066 will receive score 0.
# Unanswered question uit_020378 will receive score 0.
# Unanswered question uit_003071 will receive score 0.
# Unanswered question uit_020411 will receive score 0.
# Unanswered question uit_013642 will receive score 0.
# Unanswered question uit_013059 will receive score 0.
# Unanswered question uit_009493 will receive score 0.
# Unanswered question uit_028252 will receive score 0.
# Unanswered question uit_003854 will receive score 0.
# Unanswered question uit_025589 will receive score 0.
# Unanswered question uit_026308 will receive score 0.
# Unanswered question uit_022941 will receive score 0.
# Unanswered question uit_004137 will receive score 0.
# Unanswered question uit_000036 will receive score 0.
# Unanswered question uit_012939 will receive score 0.
# Unanswered question uit_021921 will receive score 0.
# Unanswered question uit_020098 will receive score 0.
# Unanswered question uit_027242 will receive score 0.
# Unanswered question uit_016258 will receive score 0.
# Unanswered question uit_024510 will receive score 0.
# Unanswered question uit_023894 will receive score 0.
# Unanswered question uit_008050 will receive score 0.
# Unanswered question uit_026121 will receive score 0.
# Unanswered question uit_025477 will receive score 0.
# Unanswered question uit_004379 will receive score 0.
# Unanswered question uit_026637 will receive score 0.
# Unanswered question uit_011316 will receive score 0.
# Unanswered question uit_019598 will receive score 0.
# Unanswered question uit_004256 will receive score 0.
# Unanswered question uit_006583 will receive score 0.
# Unanswered question uit_024340 will receive score 0.
# Unanswered question uit_025112 will receive score 0.
# Unanswered question uit_019331 will receive score 0.
# Unanswered question uit_008921 will receive score 0.
# Unanswered question uit_024560 will receive score 0.
# Unanswered question uit_011943 will receive score 0.
# Unanswered question uit_007714 will receive score 0.
# Unanswered question uit_008059 will receive score 0.
# Unanswered question uit_002243 will receive score 0.
# Unanswered question uit_021929 will receive score 0.
# Unanswered question uit_019762 will receive score 0.
# Unanswered question uit_027927 will receive score 0.
# Unanswered question uit_021569 will receive score 0.
# Unanswered question uit_006015 will receive score 0.
# Unanswered question uit_018986 will receive score 0.
# Unanswered question uit_025143 will receive score 0.
# Unanswered question uit_005115 will receive score 0.
# Unanswered question uit_024563 will receive score 0.
# Unanswered question uit_014164 will receive score 0.
# Unanswered question uit_001670 will receive score 0.
# Unanswered question uit_009691 will receive score 0.
# Unanswered question uit_026102 will receive score 0.
# Unanswered question uit_017248 will receive score 0.
# Unanswered question uit_005522 will receive score 0.
# Unanswered question uit_015236 will receive score 0.
# Unanswered question uit_010608 will receive score 0.
# Unanswered question uit_027266 will receive score 0.
# Unanswered question uit_025997 will receive score 0.
# Unanswered question uit_015428 will receive score 0.
# Unanswered question uit_018263 will receive score 0.
# Unanswered question uit_003636 will receive score 0.
# Unanswered question uit_001775 will receive score 0.
# Unanswered question uit_026784 will receive score 0.
# Unanswered question uit_025092 will receive score 0.
# Unanswered question uit_003888 will receive score 0.
# Unanswered question uit_014118 will receive score 0.
# Unanswered question uit_010339 will receive score 0.
# Unanswered question uit_008410 will receive score 0.
# Unanswered question uit_008676 will receive score 0.
# Unanswered question uit_009604 will receive score 0.
# Unanswered question uit_007565 will receive score 0.
# Unanswered question uit_003477 will receive score 0.
# Unanswered question uit_024902 will receive score 0.
# Unanswered question uit_003455 will receive score 0.
# Unanswered question uit_026066 will receive score 0.
# Unanswered question uit_008437 will receive score 0.
# Unanswered question uit_015124 will receive score 0.
# Unanswered question uit_010167 will receive score 0.
# Unanswered question uit_019855 will receive score 0.
# Unanswered question uit_004438 will receive score 0.
# Unanswered question uit_014347 will receive score 0.
# Unanswered question uit_000473 will receive score 0.
# Unanswered question uit_021193 will receive score 0.
# Unanswered question uit_010706 will receive score 0.
# Unanswered question uit_003582 will receive score 0.
# Unanswered question uit_026524 will receive score 0.
# Unanswered question uit_013503 will receive score 0.
# Unanswered question uit_026536 will receive score 0.
# Unanswered question uit_020529 will receive score 0.
# Unanswered question uit_003288 will receive score 0.
# Unanswered question uit_023496 will receive score 0.
# Unanswered question uit_014465 will receive score 0.
# Unanswered question uit_017293 will receive score 0.
# Unanswered question uit_019309 will receive score 0.
# Unanswered question uit_009701 will receive score 0.
# Unanswered question uit_020155 will receive score 0.
# Unanswered question uit_016631 will receive score 0.
# Unanswered question uit_026252 will receive score 0.
# Unanswered question uit_001115 will receive score 0.
# Unanswered question uit_001966 will receive score 0.
# Unanswered question uit_007708 will receive score 0.
# Unanswered question uit_021636 will receive score 0.
# Unanswered question uit_013016 will receive score 0.
# Unanswered question uit_025395 will receive score 0.
# Unanswered question uit_003395 will receive score 0.
# Unanswered question uit_027660 will receive score 0.
# Unanswered question uit_015633 will receive score 0.
# Unanswered question uit_013369 will receive score 0.
# Unanswered question uit_016545 will receive score 0.
# Unanswered question uit_007497 will receive score 0.
# Unanswered question uit_027769 will receive score 0.
# Unanswered question uit_002069 will receive score 0.
# Unanswered question uit_009770 will receive score 0.
# Unanswered question uit_007987 will receive score 0.
# Unanswered question uit_005312 will receive score 0.
# Unanswered question uit_019616 will receive score 0.
# Unanswered question uit_027278 will receive score 0.
# Unanswered question uit_013679 will receive score 0.
# Unanswered question uit_009375 will receive score 0.
# Unanswered question uit_022837 will receive score 0.
# Unanswered question uit_027276 will receive score 0.
# Unanswered question uit_016108 will receive score 0.
# Unanswered question uit_027729 will receive score 0.
# Unanswered question uit_011693 will receive score 0.
# Unanswered question uit_008938 will receive score 0.
# Unanswered question uit_009896 will receive score 0.
# Unanswered question uit_027853 will receive score 0.
# Unanswered question uit_014098 will receive score 0.
# Unanswered question uit_022059 will receive score 0.
# Unanswered question uit_005657 will receive score 0.
# Unanswered question uit_006274 will receive score 0.
# Unanswered question uit_022267 will receive score 0.
# Unanswered question uit_013441 will receive score 0.
# Unanswered question uit_003471 will receive score 0.
# Unanswered question uit_025680 will receive score 0.
# Unanswered question uit_012982 will receive score 0.
# Unanswered question uit_016007 will receive score 0.
# Unanswered question uit_005008 will receive score 0.
# Unanswered question uit_012955 will receive score 0.
# Unanswered question uit_015669 will receive score 0.
# Unanswered question uit_022776 will receive score 0.
# Unanswered question uit_017792 will receive score 0.
# Unanswered question uit_016100 will receive score 0.
# Unanswered question uit_020154 will receive score 0.
# Unanswered question uit_027678 will receive score 0.
# Unanswered question uit_001408 will receive score 0.
# Unanswered question uit_023205 will receive score 0.
# Unanswered question uit_004150 will receive score 0.
# Unanswered question uit_022154 will receive score 0.
# Unanswered question uit_023572 will receive score 0.
# Unanswered question uit_010893 will receive score 0.
# Unanswered question uit_027086 will receive score 0.
# Unanswered question uit_016071 will receive score 0.
# Unanswered question uit_023660 will receive score 0.
# Unanswered question uit_012634 will receive score 0.
# Unanswered question uit_018163 will receive score 0.
# Unanswered question uit_015985 will receive score 0.
# Unanswered question uit_021398 will receive score 0.
# Unanswered question uit_017870 will receive score 0.
# Unanswered question uit_025902 will receive score 0.
# Unanswered question uit_003293 will receive score 0.
# Unanswered question uit_028046 will receive score 0.
# Unanswered question uit_003829 will receive score 0.
# Unanswered question uit_019648 will receive score 0.
# Unanswered question uit_022612 will receive score 0.
# Unanswered question uit_003374 will receive score 0.
# Unanswered question uit_007306 will receive score 0.
# Unanswered question uit_007619 will receive score 0.
# Unanswered question uit_022816 will receive score 0.
# Unanswered question uit_008979 will receive score 0.
# Unanswered question uit_001437 will receive score 0.
# Unanswered question uit_009362 will receive score 0.
# Unanswered question uit_002247 will receive score 0.
# Unanswered question uit_015497 will receive score 0.
# Unanswered question uit_022012 will receive score 0.
# Unanswered question uit_012125 will receive score 0.
# Unanswered question uit_009324 will receive score 0.
# Unanswered question uit_013662 will receive score 0.
# Unanswered question uit_011337 will receive score 0.
# Unanswered question uit_026845 will receive score 0.
# Unanswered question uit_014878 will receive score 0.
# Unanswered question uit_005905 will receive score 0.
# Unanswered question uit_010991 will receive score 0.
# Unanswered question uit_015989 will receive score 0.
# Unanswered question uit_011520 will receive score 0.
# Unanswered question uit_004162 will receive score 0.
# Unanswered question uit_006595 will receive score 0.
# Unanswered question uit_002997 will receive score 0.
# Unanswered question uit_024163 will receive score 0.
# Unanswered question uit_017697 will receive score 0.
# Unanswered question uit_006591 will receive score 0.
# Unanswered question uit_025938 will receive score 0.
# Unanswered question uit_002807 will receive score 0.
# Unanswered question uit_003605 will receive score 0.
# Unanswered question uit_007415 will receive score 0.
# Unanswered question uit_016396 will receive score 0.
# Unanswered question uit_016407 will receive score 0.
# Unanswered question uit_026283 will receive score 0.
# Unanswered question uit_002039 will receive score 0.
# Unanswered question uit_026377 will receive score 0.
# Unanswered question uit_016727 will receive score 0.
# Unanswered question uit_019639 will receive score 0.
# Unanswered question uit_009000 will receive score 0.
# Unanswered question uit_001464 will receive score 0.
# Unanswered question uit_004327 will receive score 0.
# Unanswered question uit_000315 will receive score 0.
# Unanswered question uit_019023 will receive score 0.
# Unanswered question uit_006946 will receive score 0.
# Unanswered question uit_016979 will receive score 0.
# Unanswered question uit_021171 will receive score 0.
# Unanswered question uit_022357 will receive score 0.
# Unanswered question uit_007607 will receive score 0.
# Unanswered question uit_006961 will receive score 0.
# Unanswered question uit_003643 will receive score 0.
# Unanswered question uit_026954 will receive score 0.
# Unanswered question uit_026358 will receive score 0.
# Unanswered question uit_025025 will receive score 0.
# Unanswered question uit_010120 will receive score 0.
# Unanswered question uit_023749 will receive score 0.
# Unanswered question uit_005626 will receive score 0.
# Unanswered question uit_017376 will receive score 0.
# Unanswered question uit_012764 will receive score 0.
# Unanswered question uit_028113 will receive score 0.
# Unanswered question uit_023664 will receive score 0.
# Unanswered question uit_025778 will receive score 0.
# Unanswered question uit_020014 will receive score 0.
# Unanswered question uit_007124 will receive score 0.
# Unanswered question uit_006743 will receive score 0.
# Unanswered question uit_001846 will receive score 0.
# Unanswered question uit_019721 will receive score 0.
# Unanswered question uit_022106 will receive score 0.
# Unanswered question uit_011713 will receive score 0.
# Unanswered question uit_023649 will receive score 0.
# 10/17/2021 09:49:12 - INFO - VLSP2021_MRC.trainer -   VAL: [476/476] Elapsed 0m 29s (remain 0m 0s) Loss: 1.6713
# 10/17/2021 09:49:12 - INFO - VLSP2021_MRC.trainer -   ***** Eval results *****
# 10/17/2021 09:49:12 - INFO - VLSP2021_MRC.trainer -     exact_match = 24.2446
# 10/17/2021 09:49:12 - INFO - VLSP2021_MRC.trainer -     f1 = 37.6358
# 10/17/2021 09:49:12 - INFO - VLSP2021_MRC.trainer -     loss = 1.6713
# 10/17/2021 09:49:12 - INFO - VLSP2021_MRC.trainer -   Training total loss = 1.7278
# 10/17/2021 09:49:13 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][0/4347] Elapsed 0m 1s (remain 93m 2s) Loss: 1.7277
# 10/17/2021 09:50:34 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][100/4347] Elapsed 1m 21s (remain 57m 14s) Loss: 1.7187
# 10/17/2021 09:51:54 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][200/4347] Elapsed 2m 41s (remain 55m 40s) Loss: 1.7100
# 10/17/2021 09:53:14 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][300/4347] Elapsed 4m 2s (remain 54m 14s) Loss: 1.7018
# 10/17/2021 09:54:34 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][400/4347] Elapsed 5m 22s (remain 52m 51s) Loss: 1.6937
# 10/17/2021 09:55:54 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][500/4347] Elapsed 6m 42s (remain 51m 28s) Loss: 1.6870
# 10/17/2021 09:57:15 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][600/4347] Elapsed 8m 2s (remain 50m 7s) Loss: 1.6798
# 10/17/2021 09:58:35 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][700/4347] Elapsed 9m 22s (remain 48m 46s) Loss: 1.6727
# 10/17/2021 09:59:55 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][800/4347] Elapsed 10m 42s (remain 47m 26s) Loss: 1.6662
# 10/17/2021 10:01:15 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][900/4347] Elapsed 12m 3s (remain 46m 5s) Loss: 1.6605
# 10/17/2021 10:02:35 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][1000/4347] Elapsed 13m 23s (remain 44m 45s) Loss: 1.6531
# 10/17/2021 10:03:55 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][1100/4347] Elapsed 14m 43s (remain 43m 24s) Loss: 1.6475
# 10/17/2021 10:05:16 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][1200/4347] Elapsed 16m 3s (remain 42m 4s) Loss: 1.6419
# 10/17/2021 10:06:36 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][1300/4347] Elapsed 17m 23s (remain 40m 43s) Loss: 1.6361
# 10/17/2021 10:07:56 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][1400/4347] Elapsed 18m 43s (remain 39m 23s) Loss: 1.6298
# 10/17/2021 10:09:16 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][1500/4347] Elapsed 20m 3s (remain 38m 2s) Loss: 1.6238
# 10/17/2021 10:10:36 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][1600/4347] Elapsed 21m 23s (remain 36m 42s) Loss: 1.6180
# 10/17/2021 10:11:56 - INFO - VLSP2021_MRC.trainer -   Epoch: [3][1700/4347] Elapsed 22m 44s (remain 35m 21s) Loss: 1.6117

# %%
pred = trainer.evaluate("dev",out_pred=True)
# Out:
# 10/17/2021 07:32:55 - INFO - VLSP2021_MRC.trainer -   ***** Running evaluation on dev dataset *****
# 10/17/2021 07:32:55 - INFO - VLSP2021_MRC.trainer -     Num examples = 28
# 10/17/2021 07:32:55 - INFO - VLSP2021_MRC.trainer -     Batch size = 8
# 10/17/2021 07:32:57 - INFO - VLSP2021_MRC.trainer -   VAL: [4/4] Elapsed 0m 0s (remain 0m 0s) Loss: 5.2583
# 10/17/2021 07:32:57 - INFO - VLSP2021_MRC.trainer -   ***** Eval results *****
# 10/17/2021 07:32:57 - INFO - VLSP2021_MRC.trainer -     exact_match = 0.0000
# 10/17/2021 07:32:57 - INFO - VLSP2021_MRC.trainer -     f1 = 7.7357
# 10/17/2021 07:32:57 - INFO - VLSP2021_MRC.trainer -     loss = 5.2583

# %%
pred
# Out:
# [OrderedDict([('text', 'suất thấp của tiền gửi ngân hàng.'),
#               ('probability', 0.05170219820190293),
#               ('start_logit', 0.6922128796577454),
#               ('end_logit', 0.9497385025024414),
#               ('start_index', 69),
#               ('end_index', 75),
#               ('qas_id', 'uit_015587')]),
#  OrderedDict([('text',
#                '1997; Rowe hạ sinh thêm bé gái Paris-Michael Katherine Jackson vào ngày 3 tháng 4 năm 1998. Cả hai ly hôn năm 1999'),
#               ('probability', 0.06081818457403736),
#               ('start_logit', 1.0934288501739502),
#               ('end_logit', 0.9688441157341003),
#               ('start_index', 209),
#               ('end_index', 231),
#               ('qas_id', 'uit_008735')]),
#  OrderedDict([('text',
#                'diễu hành, những người hoàn toàn xa lạ ôm choàng lấy nhau.'),
#               ('probability', 0.05560178677764208),
#               ('start_logit', 0.7965071201324463),
#               ('end_logit', 1.103086233139038),
#               ('start_index', 43),
#               ('end_index', 54),
#               ('qas_id', 'uit_021854')]),
#  OrderedDict([('text',
#                '1567) thời Mục Tông, Uy khấu dần được bình định, triều đình nhận thấy tính quan trọng của mậu dịch đối ngoại đối với cư dân ven biển, do đó từng bước giải trừ hải cấm, khiến mậu dịch bí mật trong dân gian được hợp pháp hóa, mậu dịch quốc tế sôi động khiến Trung Quốc tiến vào hệ thống mậu dịch thế giới đang dần thành hình.'),
#               ('probability', 0.05884748477563389),
#               ('start_logit', 0.9076266288757324),
#               ('end_logit', 1.0355137586593628),
#               ('start_index', 266),
#               ('end_index', 334),
#               ('qas_id', 'uit_018747')]),
#  OrderedDict([('text',
#                'khi được gọi là Cuộc đại khởi nghĩa, là cuộc khởi nghĩa đầu tiên trong ba cuộc khởi nghĩa lớn của người Do Thái ở tỉnh Judaea chống lại Đế quốc La Mã.'),
#               ('probability', 0.061594488006458024),
#               ('start_logit', 0.9084529876708984),
#               ('end_logit', 1.3563517332077026),
#               ('start_index', 10),
#               ('end_index', 42),
#               ('qas_id', 'uit_020519')]),
#  OrderedDict([('text', 'chính trị của Stalin. Thay vào đó, Phát xít'),
#               ('probability', 0.05498078486945553),
#               ('start_logit', 0.7968122363090515),
#               ('end_logit', 1.1288379430770874),
#               ('start_index', 104),
#               ('end_index', 112),
#               ('qas_id', 'uit_009913')]),
#  OrderedDict([('text',
#                'thập niên. Tuy nhiên, đảng Cộng hòa lấy lại thế cờ vào năm 1966 và đưa Richard Nixon đắc cử tổng thống vào năm 1968. Nixon phần nhiều tiếp tục các chương trình New Deal và xã hội vĩ đại mà ông kế thừa. Chủ nghĩa'),
#               ('probability', 0.0578728693927003),
#               ('start_logit', 0.9233971834182739),
#               ('end_logit', 1.3092141151428223),
#               ('start_index', 42),
#               ('end_index', 87),
#               ('qas_id', 'uit_018206')]),
#  OrderedDict([('text',
#                'có thể dẫn đến thần thánh hoá, và các di tích lịch sử Hồi giáo quan trọng nhất (tại Mecca và Medina) nằm tại khu vực Hejaz. Kết quả là, dưới quyền cai trị của gia tộc Saud, khoảng 95% toà nhà lịch sử của Mecca đã bị phá huỷ vì lý'),
#               ('probability', 0.060365364297580035),
#               ('start_logit', 0.7514287829399109),
#               ('end_logit', 1.183184027671814),
#               ('start_index', 25),
#               ('end_index', 76),
#               ('qas_id', 'uit_007353')]),
#  OrderedDict([('text',
#                '1513) thời Vũ Tông, Quốc vương Bồ Dào Nha Emmanuel I vì muốn thông thương với triều đình Minh nên phái đoàn sứ giả đến Trung Quốc. Đoàn sứ giả muốn đổ bộ tại Quảng Châu, song bị từ chối nhập cảnh. Họ chuyển sang dùng vũ lực chiếm cứ Đồn Môn, bùng phát Hải chiến Đồn Môn, Bộ chiến Tây Thảo Loan với triều Minh, kết quả chiến bại. Cuối cùng, Gia Tĩnh Đế đồng ý cho đoàn nhập cảnh, cùng lúc nhượng Áo Môn cho người Bồ Đào Nha, chấp thuận cho họ đến Quảng Châu mỗi năm, đây là lần đầu tiên cường quốc phương tây chính'),
#               ('probability', 0.060496943530818935),
#               ('start_logit', 1.0218175649642944),
#               ('end_logit', 1.0877028703689575),
#               ('start_index', 53),
#               ('end_index', 162),
#               ('qas_id', 'uit_018765')]),
#  OrderedDict([('text', 'trong đó'),
#               ('probability', 0.06649875691447006),
#               ('start_logit', 0.8788336515426636),
#               ('end_logit', 1.215957522392273),
#               ('start_index', 18),
#               ('end_index', 19),
#               ('qas_id', 'uit_010718')]),
#  OrderedDict([('text', 'năm 1992'),
#               ('probability', 0.06720390303885118),
#               ('start_logit', 0.9574524760246277),
#               ('end_logit', 1.5402110815048218),
#               ('start_index', 78),
#               ('end_index', 79),
#               ('qas_id', 'uit_007104')]),
#  OrderedDict([('text',
#                'bé 10 tuổi Einstein những quyển sách cơ bản của khoa học, toán học và triết học, bao gồm Phê bình lý luận thuần túy của Immanuel Kant và cuốn Cơ bản của Euclid (sau này Einstein gọi là "sách hình học nhỏ thần thánh"). Talmud là một sinh viên y khoa Do thái nghèo đến từ Ba Lan. Cộng đồng người Do thái sắp xếp cho Talmud ăn cùng với Einstein vào các ngày thứ Năm trong tuần trong vòng sáu năm. Trong thời gian này Talmud đã tận tâm hướng dẫn Einstein đến với nhiều chủ đề thú vị.[fn'),
#               ('probability', 0.05283417521560549),
#               ('start_logit', 0.8505042791366577),
#               ('end_logit', 1.0696723461151123),
#               ('start_index', 77),
#               ('end_index', 177),
#               ('qas_id', 'uit_001073')]),
#  OrderedDict([('text',
#                'kỷ 17, nhờ Jean-Baptiste Colbert, thư viện có những bước tiến mạnh mẽ và đạt đến giai đoạn hoàng kim trong suốt những năm của thế kỷ 18. Trở thành thư viện quốc gia vào thời kỳ Cách mạng, thư viện không ngừng đón nhận những bộ sưu tập sách được đưa về từ khắp Paris và nước Pháp, rồi từ cả những quốc gia láng giềng.'),
#               ('probability', 0.061133904012039116),
#               ('start_logit', 1.0845922231674194),
#               ('end_logit', 1.2340630292892456),
#               ('start_index', 78),
#               ('end_index', 144),
#               ('qas_id', 'uit_002265')]),
#  OrderedDict([('text',
#                '.800 kilômét (3.000 dặm) từ cực bắc British Columbia (Canada) đến New Mexico (Hoa Kỳ). Đỉnh'),
#               ('probability', 0.05855376756357692),
#               ('start_logit', 1.032819390296936),
#               ('end_logit', 0.928795576095581),
#               ('start_index', 39),
#               ('end_index', 54),
#               ('qas_id', 'uit_021192')]),
#  OrderedDict([('text', 'dân Đảng hoạt động, Việt Nam Dân chủ'),
#               ('probability', 0.06606449833235627),
#               ('start_logit', 0.9231462478637695),
#               ('end_logit', 1.3612574338912964),
#               ('start_index', 7),
#               ('end_index', 14),
#               ('qas_id', 'uit_027835')]),
#  OrderedDict([('text',
#                '100 triệu người vào năm 2050 và 64 triệu người vào năm 2100.'),
#               ('probability', 0.05464490647021296),
#               ('start_logit', 0.8423077464103699),
#               ('end_logit', 0.7964295744895935),
#               ('start_index', 84),
#               ('end_index', 96),
#               ('qas_id', 'uit_000912')]),
#  OrderedDict([('text',
#                'Đảng Bolshevik đã kêu gọi và tổ chức công nhân và nhân dân bảo vệ thủ đô Petrograd.'),
#               ('probability', 0.061843789417980674),
#               ('start_logit', 0.8958993554115295),
#               ('end_logit', 1.2599517107009888),
#               ('start_index', 31),
#               ('end_index', 48),
#               ('qas_id', 'uit_011123')]),
#  OrderedDict([('text',
#                'dân Đảng tại Quảng Tây dưới quyền Tân Quế hệ của Bạch Sùng Hy và Lý Tông Nhân thi hành các chính sách chống chủ nghĩa'),
#               ('probability', 0.05804098386537899),
#               ('start_logit', 1.2162015438079834),
#               ('end_logit', 1.059441328048706),
#               ('start_index', 4),
#               ('end_index', 29),
#               ('qas_id', 'uit_017371')]),
#  OrderedDict([('text',
#                'theo lệnh Đồng Minh vào giám sát quân Nhật đầu hàng nhưng đồng thời cũng tạo điều kiện cho quân Pháp vào Nam Bộ.'),
#               ('probability', 0.05236010485634441),
#               ('start_logit', 0.6173076033592224),
#               ('end_logit', 1.0076614618301392),
#               ('start_index', 35),
#               ('end_index', 58),
#               ('qas_id', 'uit_027367')]),
#  OrderedDict([('text',
#                '1915, ông đã công bố thuyết tương đối rộng theo dạng ngày nay của lý thuyết.'),
#               ('probability', 0.05757972672953348),
#               ('start_logit', 0.8901594281196594),
#               ('end_logit', 1.263118028640747),
#               ('start_index', 152),
#               ('end_index', 167),
#               ('qas_id', 'uit_001298')])]

# %%
dev_answers
# Out:
# [{'answers': {'answer_start': [201],
#    'text': ['quyết định thâm nhập thị trường cổ phiếu']},
#   'id': 'uit_015587'},
#  {'answers': {'answer_start': [152],
#    'text': ['82 đêm nhạc tại 58 thành phố, đi qua 5 châu lục và 35 quốc gia, phục vụ hơn 4.5 triệu người hâm mộ']},
#   'id': 'uit_008735'},
#  {'answers': {'answer_start': [458], 'text': ['tặng 100 DM khi qua cổng']},
#   'id': 'uit_021854'},
#  {'answers': {'answer_start': [1261],
#    'text': ['triều đình nhận thấy tính quan trọng của mậu dịch đối ngoại đối với cư dân ven biển']},
#   'id': 'uit_018747'},
#  {'answers': {'answer_start': [800],
#    'text': ['Cả hai cuộc khởi nghĩa này đều bị đàn áp dã man']},
#   'id': 'uit_020519'},
#  {'answers': {'answer_start': [152],
#    'text': ['sự cai trị hà khắc của người Đức tại các vùng lãnh thổ chiếm đóng']},
#   'id': 'uit_009913'},
#  {'answers': {'answer_start': [453],
#    'text': ['Ronald Reagan được bầu làm tổng thống vào năm 1980']},
#   'id': 'uit_018206'},
#  {'answers': {'answer_start': [100],
#    'text': ['vì lo ngại có thể dẫn đến thần thánh hoá']},
#   'id': 'uit_007353'},
#  {'answers': {'answer_start': [181],
#    'text': ['lập cứ điểm mậu dịch tại Trung Quốc']},
#   'id': 'uit_018765'},
#  {'answers': {'answer_start': [169], 'text': ['10.294.289']},
#   'id': 'uit_010718'},
#  {'answers': {'answer_start': [538], 'text': ['do Quốc vương lựa chọn']},
#   'id': 'uit_007104'},
#  {'answers': {'answer_start': [287], 'text': ['Năm 1889']},
#   'id': 'uit_001073'},
#  {'answers': {'answer_start': [143], 'text': ['François I']},
#   'id': 'uit_002265'},
#  {'answers': {'answer_start': [518],
#    'text': ['dãy núi Cascade và dãy núi Duyên hải Thái Bình Dương (Pacific Coast Ranges)']},
#   'id': 'uit_021192'},
#  {'answers': {'answer_start': [404],
#    'text': ['bất đồng quan điểm về việc thực hiện cách mạng xã hội và cách đối phó với việc Đồng Minh đổ bộ vào Nam Kỳ']},
#   'id': 'uit_027835'},
#  {'answers': {'answer_start': [57],
#    'text': ['sự suy giảm lực lượng lao động đồng thời gia tăng chi phí cho phúc lợi xã hội như vấn đề lương hưu']},
#   'id': 'uit_000912'},
#  {'answers': {'answer_start': [258],
#    'text': ['phá hoại ngầm các đoàn tàu chuyên chở quân của Kornilov']},
#   'id': 'uit_011123'},
#  {'answers': {'answer_start': [123],
#    'text': ['chống chủ nghĩa đế quốc, chống tôn giáo và chống ngoại quốc']},
#   'id': 'uit_017371'},
#  {'answers': {'answer_start': [120], 'text': ['liên quân Anh-Pháp']},
#   'id': 'uit_027367'},
#  {'answers': {'answer_start': [0], 'text': ['Năm 1912']}, 'id': 'uit_001298'}]
